# %%
import json

# %%
jsonResponse = {
    "pageDto": {
        "createUserId": 31730,
        "createTime": 1517567209658,
        "updateUserId": 31730,
        "updateTime": 1517575716008,
        "updateUser": "Apolo Siskos",
        "createUser": "Apolo Siskos",
        "id": 1525673,
        "dashboardId": 77319,
        "name": "page 7",
        "ordinal": 10,
        "isPublished": 'false',
        "description": 'null',
        "config": {
            "filter": {
                "dingoDimensionFilter": 'null',
                "dingoMeasurementFilters": 'null',
                "filterDims": {
                    "CAMPAIGN_KEY": {
                        "vals": [
                            "45221"
                        ],
                        "qVals": 'null',
                        "emptyQVals": 'null'
                    },
                    "BRAND_DATA_SOURCE_INSTANCE": {
                        "vals": [
                            "Bionic V13 Net",
                            "DBM CHECK",
                            "TRUVIEW CHECK"
                        ],
                        "qVals": 'null',
                        "emptyQVals": 'null'
                    }
                },
                "date": {
                    "dateRangeType": "CUSTOM",
                    "startDate": "2016-04-01",
                    "endDate": "2019-01-31",
                    "relativeDateType": 'null',
                    "relativeDate": 'null',
                    "filterDatePeriod": 'null'
                },
                "linkage": 'null',
                "stringDimensionFiltersOperator": "AND",
                "numberDimensionFiltersOperator": "AND",
                "stringDimensionFilters": 'null',
                "measurementFilters": 'null',
                "unlinkedStringDimensionFilters": 'null',
                "unlinkedMeasurementFilters": 'null'
            },
            "exportSplitHeights": 'null',
            "widgetFilters": 'null',
            "widgetToggle": 'null',
            "chatChannel": 'null',
            "toggleExist": 'false'
        },
        "brandId": 11839,
        "dashboardName": "Test",
        "dashboardIsTemplate": 'false',
        "thumbUrl": 'null',
        "uiTheme": 'null',
        "dashboardThemeId": 'null',
        "embedToken": 'null',
        "embedStatus": 'null',
        "isTemplate": 'false',
        "thumbUrlUpdateTime": 'null',
        "isLocalTemplate": 'null',
        "originalId": 'null',
        "isNeedUpdateThumbUrl": 'true',
        "isSecureEmbed": 'false',
        "isTempForExport": 'null',
        "userUpdateTime": 1517575715996,
        "templatePageId": 'null'
    },
    "pageWidgets": [
        {
            "createUserId": 31730,
            "createTime": 1517567379346,
            "updateUserId": 31730,
            "updateTime": 1517575716196,
            "updateUser": "Apolo Siskos",
            "createUser": "Apolo Siskos",
            "id": 31934964,
            "name": "Bar Graph",
            "dashboardPageId": 1525673,
            "dashboardPageName": "page 7",
            "dashboardPageIsTemplate": 'false',
            "dashboardPageIsDeleted": 'false',
            "dashboardId": 77319,
            "dashboardName": "Test",
            "dashboardIsTemplate": 'false',
            "widgetId": 7,
            "config": {
                "filter": {
                    "dingoDimensionFilter": 'null',
                    "dingoMeasurementFilters": 'null',
                    "filterDims": {},
                    "date": {
                        "dateRangeType": "CUSTOM",
                        "startDate": "2016-04-01",
                        "endDate": "2019-01-31",
                        "relativeDateType": 'null',
                        "relativeDate": 'null',
                        "filterDatePeriod": 'null'
                    },
                    "linkage": {},
                    "stringDimensionFiltersOperator": "AND",
                    "numberDimensionFiltersOperator": "AND",
                    "stringDimensionFilters": [],
                    "measurementFilters": [],
                    "unlinkedStringDimensionFilters": 'null',
                    "unlinkedMeasurementFilters": 'null'
                },
                "sortInfo": {
                    "sortIndex": 'null',
                    "metric": "DATE_DAY",
                    "sortOrder": "ASC"
                },
                "secondLevelSortInfo": 'null',
                "metrics": [
                    {
                        "name": "DELIVERY_IMPRESSIONS",
                        "label": 'null',
                        "displayType": "column",
                        "lineType": 'null',
                        "markerType": 'null',
                        "markerVisibility": 'null',
                        "color": 'null',
                        "precision": 'null',
                        "friendlyFormatting": 'null',
                        "measurementType": 'null',
                        "currencySymbol": 'null',
                        "minVal": 'null',
                        "maxVal": 'null',
                        "axisIndex": "0",
                        "shareOfTotal": 'null',
                        "highlightingRules": 'null',
                        "timeCompareType": "NONE",
                        "timeCompareMethod": "PREVIOUS_DAY",
                        "timeCompareIndicator": "NO",
                        "timeCompareShowName": "",
                        "timeCompareShowCompareValue": "YES",
                        "showLabels": 'null',
                        "showAverage": 'null',
                        "showLinearTrendline": 'null',
                        "showLogarithmicTrendline": 'null',
                        "showPowerTrendline": 'null',
                        "showExponentialTrendline": 'null',
                        "showCumulative": 'null',
                        "showForecast": 'null',
                        "forecastSettings": 'null',
                        "showMovingAverage": 'null',
                        "showMovingAverageVal": 'null',
                        "invertAxis": 'null',
                        "isTrackable": 'null'
                    }
                ],
                "timeBreakdown": 'null',
                "rowDims": [
                    "DATE_DAY"
                ],
                "dimensionsDetails": 'null',
                "uiFilters": 'null',
                "uiLabels": 'null',
                "columns": 'null',
                "collapsedRows": 'null',
                "validMeasure": 'false',
                "queryByUpdateDate": 'null',
                "filterGUID": "d8e9110c-fa50-0432-d4bd-78f7ab798bda",
                "col": 1,
                "row": 1,
                "sizex": 15,
                "sizey": 12,
                "data": 'null',
                "goals": 'null',
                "goalShowDimOnBars": 'null',
                "topFilter": {
                    "amount": 20,
                    "group": 'null',
                    "optional": 'null'
                },
                "compareOptions": 'null',
                "compareDates": 'null',
                "isStacked": 'false',
                "isStackedSecondMetric": 'false',
                "isStackedPercent": 'false',
                "isStackedPercentSecondMetric": 'false',
                "isStackedBars": 'false',
                "isShowCompareChange": 'false',
                "compareChange": 'null',
                "isShowColoring": 'false',
                "isShowRevertCompare": 'false',
                "maps": 'null',
                "isShowCity": 'false',
                "legendPosition": 'null',
                "legendFloating": 'false',
                "isShowZipCode": 'false',
                "isShowCross": 'false',
                "crossTabRows": 'null',
                "crossTabColumns": 'null',
                "isShowPieAbsNumbers": 'false',
                "vennCircleSize": 'null',
                "isShowTranspose": 'false',
                "isShowWrapText": 'false',
                "isShowHitmapValues": 'false',
                "isShowHitmapRevertIndication": 'false',
                "isShowTotals": 'true',
                "isShowRowTotals": 'true',
                "isShowLegend": 'true',
                "isShowAsHeatmap": 'false',
                "isShowPacingMetrics": 'false',
                "isShowLabels": 'false',
                "isInheritPageFilters": 'false',
                "isShowGoalDateLast": 'false',
                "isShowFirstDate": 'false',
                "isShowFirstCalendricDate": 'false',
                "calcFunctions": 'null',
                "calcFunctionsParams": 'null',
                "googleAnalyticsConfig": 'null',
                "timelineConfig": 'null',
                "dataLabel": 'null',
                "displayDateRange": 'null',
                "hierarchyDrillDown": 1,
                "showSideTable": 'false',
                "currentDate": 'null',
                "isAutoCenterImg": 'false',
                "isAutoSizeImg": 'false',
                "isBackgroundTransparent": 'false',
                "backgroundColor": 'null',
                "coloring": 'null',
                "scaleLabelType": 'null',
                "gaugeFilledColor": 'null',
                "gaugeMaxValue": 'null',
                "gaugeFilledColorType": 'null',
                "rateTypeCalculation": 'null',
                "qSelected": 'null',
                "uiShowSettings": [
                    "UI_SETTINGS_SET",
                    "CALENDAR_EVENTS"
                ],
                "calendarEventsTags": 'null',
                "freezeColumns": 'null',
                "pageSize": 'null',
                "widgetFilteringMethod": 'null',
                "widgetFilteringDisplay": 'null',
                "widgetFilteringListShowSearch": 'true',
                "widgetFilteringCascadingFilter": 'false',
                "widgetFilteringListShowType": 'null',
                "widgetFilteringSpecificWidgets": 'null',
                "isWidgetFilteringWithCustomValues": 'false',
                "widgetFilteringCustomDimensionValues": 'null',
                "widgetFilteringOperator": 'null',
                "widgetFilteringMustSelected": 'false',
                "widgetFilteringDefaultValues": 'null',
                "widgetDateFilteringIsToRestrictDateRange": 'false',
                "widgetDateFilteringRestrictDate": 'null',
                "widgetDateFilteringIsToApplyDefaultDate": 'false',
                "widgetDateFilteringApplyDate": 'null',
                "widgetDateFilteringShowCompareMethod": 'false',
                "widgetDateFilteringDefaultCompareMethod": 'null',
                "tokenSettings": 'null',
                "tokenSeparator": 'null',
                "useCustomCss": 'false',
                "advancedRichTextEditor": 'false',
                "nonRestrictedIframe": 'false',
                "inheritBrandCustomCss": 'false',
                "customCss": 'null',
                "secondLevelFilter": 'null',
                "id": 'null',
                "widgetGUID": 'null'
            },
            "embedToken": 'null',
            "note": 'null',
            "noteConfig": 'null',
            "isSecureEmbed": 'null',
            "hasTrackedMetric": 'false'
        },
        {
            "createUserId": 31730,
            "createTime": 1517575716221,
            "updateUserId": 31730,
            "updateTime": 1517575716221,
            "updateUser": "Apolo Siskos",
            "createUser": "Apolo Siskos",
            "id": 31938500,
            "name": "",
            "dashboardPageId": 1525673,
            "dashboardPageName": "page 7",
            "dashboardPageIsTemplate": 'false',
            "dashboardPageIsDeleted": 'false',
            "dashboardId": 77319,
            "dashboardName": "Test",
            "dashboardIsTemplate": 'false',
            "widgetId": 9,
            "config": {
                "filter": {
                    "dingoDimensionFilter": 'null',
                    "dingoMeasurementFilters": 'null',
                    "filterDims": {},
                    "date": {
                        "dateRangeType": 'null',
                        "startDate": 'null',
                        "endDate": 'null',
                        "relativeDateType": 'null',
                        "relativeDate": 'null',
                        "filterDatePeriod": 'null'
                    },
                    "linkage": {},
                    "stringDimensionFiltersOperator": "AND",
                    "numberDimensionFiltersOperator": "AND",
                    "stringDimensionFilters": [],
                    "measurementFilters": [],
                    "unlinkedStringDimensionFilters": 'null',
                    "unlinkedMeasurementFilters": 'null'
                },
                "sortInfo": {
                    "sortIndex": 'null',
                    "metric": 'null',
                    "sortOrder": "DESC"
                },
                "secondLevelSortInfo": 'null',
                "metrics": 'null',
                "timeBreakdown": 'null',
                "rowDims": 'null',
                "dimensionsDetails": 'null',
                "uiFilters": 'null',
                "uiLabels": 'null',
                "columns": 'null',
                "collapsedRows": 'null',
                "validMeasure": 'false',
                "queryByUpdateDate": 'null',
                "filterGUID": "15c1a131-c829-61c4-b163-caed42a2060c",
                "col": 16,
                "row": 1,
                "sizex": 15,
                "sizey": 12,
                "data": "aaaaaaaaa",
                "goals": 'null',
                "goalShowDimOnBars": 'null',
                "topFilter": {
                    "amount": 50,
                    "group": 'null',
                    "optional": 'false'
                },
                "compareOptions": 'null',
                "compareDates": 'null',
                "isStacked": 'false',
                "isStackedSecondMetric": 'false',
                "isStackedPercent": 'false',
                "isStackedPercentSecondMetric": 'false',
                "isStackedBars": 'false',
                "isShowCompareChange": 'false',
                "compareChange": 'null',
                "isShowColoring": 'false',
                "isShowRevertCompare": 'false',
                "maps": 'null',
                "isShowCity": 'false',
                "legendPosition": 'null',
                "legendFloating": 'false',
                "isShowZipCode": 'false',
                "isShowCross": 'false',
                "crossTabRows": 'null',
                "crossTabColumns": 'null',
                "isShowPieAbsNumbers": 'false',
                "vennCircleSize": 'null',
                "isShowTranspose": 'false',
                "isShowWrapText": 'false',
                "isShowHitmapValues": 'false',
                "isShowHitmapRevertIndication": 'false',
                "isShowTotals": 'true',
                "isShowRowTotals": 'true',
                "isShowLegend": 'true',
                "isShowAsHeatmap": 'false',
                "isShowPacingMetrics": 'false',
                "isShowLabels": 'false',
                "isInheritPageFilters": 'false',
                "isShowGoalDateLast": 'false',
                "isShowFirstDate": 'false',
                "isShowFirstCalendricDate": 'false',
                "calcFunctions": 'null',
                "calcFunctionsParams": 'null',
                "googleAnalyticsConfig": 'null',
                "timelineConfig": {
                    "startDate": "",
                    "endDate": 'null',
                    "width": 'null'
                },
                "dataLabel": 'null',
                "displayDateRange": 'null',
                "hierarchyDrillDown": 'null',
                "showSideTable": 'false',
                "currentDate": 'null',
                "isAutoCenterImg": 'false',
                "isAutoSizeImg": 'false',
                "isBackgroundTransparent": 'false',
                "backgroundColor": 'null',
                "coloring": 'null',
                "scaleLabelType": 'null',
                "gaugeFilledColor": 'null',
                "gaugeMaxValue": 'null',
                "gaugeFilledColorType": 'null',
                "rateTypeCalculation": 'null',
                "qSelected": 'null',
                "uiShowSettings": 'null',
                "calendarEventsTags": 'null',
                "freezeColumns": 'null',
                "pageSize": 'null',
                "widgetFilteringMethod": 'null',
                "widgetFilteringDisplay": 'null',
                "widgetFilteringListShowSearch": 'true',
                "widgetFilteringCascadingFilter": 'false',
                "widgetFilteringListShowType": 'null',
                "widgetFilteringSpecificWidgets": 'null',
                "isWidgetFilteringWithCustomValues": 'false',
                "widgetFilteringCustomDimensionValues": 'null',
                "widgetFilteringOperator": 'null',
                "widgetFilteringMustSelected": 'false',
                "widgetFilteringDefaultValues": 'null',
                "widgetDateFilteringIsToRestrictDateRange": 'false',
                "widgetDateFilteringRestrictDate": 'null',
                "widgetDateFilteringIsToApplyDefaultDate": 'false',
                "widgetDateFilteringApplyDate": 'null',
                "widgetDateFilteringShowCompareMethod": 'false',
                "widgetDateFilteringDefaultCompareMethod": 'null',
                "tokenSettings": "CONCATINATE",
                "tokenSeparator": ", ",
                "useCustomCss": 'false',
                "advancedRichTextEditor": 'false',
                "nonRestrictedIframe": 'false',
                "inheritBrandCustomCss": 'false',
                "customCss": 'null',
                "secondLevelFilter": 'null',
                "id": 'null',
                "widgetGUID": 'null'
            },
            "embedToken": 'null',
            "note": 'null',
            "noteConfig": 'null',
            "isSecureEmbed": 'null',
            "hasTrackedMetric": 'null'
        }
    ],
    "goals": [
        {
            "createUserId": 19532,
            "createTime": 1510500774905,
            "updateUserId": 19532,
            "updateTime": 1510505159199,
            "updateUser": "Dave Wilkinson",
            "createUser": "Dave Wilkinson",
            "id": 74627,
            "name": "Daily Pace Goal",
            "config": {
                "filter": {
                    "dingoDimensionFilter": 'null',
                    "dingoMeasurementFilters": 'null',
                    "filterDims": {},
                    "date": {
                        "dateRangeType": "CUSTOM",
                        "startDate": "2017-07-01",
                        "endDate": "2017-09-30",
                        "relativeDateType": 'null',
                        "relativeDate": 'null',
                        "filterDatePeriod": 'null'
                    },
                    "linkage": 'null',
                    "stringDimensionFiltersOperator": "AND",
                    "numberDimensionFiltersOperator": "AND",
                    "stringDimensionFilters": [],
                    "measurementFilters": [],
                    "unlinkedStringDimensionFilters": 'null',
                    "unlinkedMeasurementFilters": 'null'
                },
                "sortInfo": 'null',
                "secondLevelSortInfo": 'null',
                "metrics": 'null',
                "timeBreakdown": 'null',
                "rowDims": 'null',
                "dimensionsDetails": 'null',
                "uiFilters": 'null',
                "uiLabels": 'null',
                "columns": 'null',
                "collapsedRows": 'null',
                "validMeasure": 'false',
                "queryByUpdateDate": 'null',
                "runAfterDS": [],
                "values": [
                    {
                        "dimension": 'null',
                        "periodStart": 'null',
                        "periodEnd": 'null',
                        "periodDate": 'null',
                        "periodName": 'null',
                        "goal": 'null'
                    }
                ],
                "goalLastResponse": {
                    "error": 'null',
                    "goalId": 74627,
                    "goalName": "Daily Pace Goal",
                    "details": [],
                    "totalDetails": {
                        "dimensions": [],
                        "dimensionValues": [],
                        "measurementValue": 6122137.168171044,
                        "predictionSamplingValue": 6122137.168171044,
                        "goalValue": 22537.0,
                        "newGoalValue": 'null',
                        "periodStart": "2017-07-01",
                        "periodEnd": "2017-09-30",
                        "rateCalculationType": 'null',
                        "goalFillType": 'null',
                        "periodDaysElapsed": 92,
                        "periodDaysLeft": 0,
                        "remainingValue": -6099600.168171044,
                        "dailyTarget": 'null',
                        "dailyAvgGoal": 'null',
                        "dailyAvgValue": 'null',
                        "predictedValue": 'null',
                        "deliveryRate": 27164.827475578135,
                        "goalStatus": "GOOD"
                    },
                    "calcType": 'null',
                    "dingoException": 'null'
                },
                "goalRanges": [
                    82.0,
                    118.0
                ],
                "includeSun": 'true',
                "includeMon": 'true',
                "includeTue": 'true',
                "includeWed": 'true',
                "includeThu": 'true',
                "includeFri": 'true',
                "includeSat": 'true',
                "valuesFillType": "AUTO",
                "valuesFillMeasurement": "CALC_228163",
                "predictionSamplingType": "GOAL_RANGE",
                "predictionSamplingDays": 'null',
                "rateCalculationType": "ENTIRE_GOAL",
                "emailNotificationSortBy": "DELIVERY_MEDIA_COST",
                "emailNotificationSortOrder": "ACS",
                "actionsActive": 'false',
                "disableActionAfterRun": 'false',
                "actionsOnAchieve": [],
                "actionsOnNotAchieve": [],
                "actionsRunType": "EACH_ROW",
                "isCalcGoalNewWay": 'true'
            },
            "brandId": 11839,
            "target": 0.0,
            "targetType": "MIN_LIMIT",
            "dimensionTarget": 0.0,
            "dimensionTargetType": "MIN_LIMIT",
            "showInNotificationsPane": 'false',
            "emailRecipients": "",
            "goalMeasurement": "DELIVERY_MEDIA_COST",
            "goalMeasurementType": "NOT_SUM",
            "goalType": "AT_LEAST",
            "periodGranularity": "DATE_DAY",
            "goalDimension": "CAMPAIGN_KEY",
            "goalDimensionHierarchyId": 'null',
            "goalGranularity": "SINGLE_GOAL_FOR_ALL_ENTITIES",
            "originalId": 'null'
        },
        {
            "createUserId": 19715,
            "createTime": 1491857531434,
            "updateUserId": 1,
            "updateTime": 1505838053197,
            "updateUser": "System Administrator",
            "createUser": "Dave Wilkinson",
            "id": 53401,
            "name": "US DC Test",
            "config": {
                "filter": {
                    "dingoDimensionFilter": 'null',
                    "dingoMeasurementFilters": 'null',
                    "filterDims": {
                        "BRAND_DATA_SOURCE_INSTANCE": {
                            "vals": [
                                "Plans V4",
                                "S3 - DoubleClick US (RAW)"
                            ],
                            "qVals": 'null',
                            "emptyQVals": 'null'
                        }
                    },
                    "date": {
                        "dateRangeType": "THIS_MONTH",
                        "startDate": "2017-04-01",
                        "endDate": "2017-04-30",
                        "relativeDateType": 'null',
                        "relativeDate": 'null',
                        "filterDatePeriod": 'null'
                    },
                    "linkage": 'null',
                    "stringDimensionFiltersOperator": "AND",
                    "numberDimensionFiltersOperator": "AND",
                    "stringDimensionFilters": [],
                    "measurementFilters": [],
                    "unlinkedStringDimensionFilters": 'null',
                    "unlinkedMeasurementFilters": 'null'
                },
                "sortInfo": 'null',
                "secondLevelSortInfo": 'null',
                "metrics": 'null',
                "timeBreakdown": 'null',
                "rowDims": 'null',
                "dimensionsDetails": 'null',
                "uiFilters": 'null',
                "uiLabels": 'null',
                "columns": 'null',
                "collapsedRows": 'null',
                "validMeasure": 'false',
                "queryByUpdateDate": 'null',
                "runAfterDS": [],
                "values": [
                    {
                        "dimension": 'null',
                        "periodStart": 'null',
                        "periodEnd": 'null',
                        "periodDate": 'null',
                        "periodName": 'null',
                        "goal": 'null'
                    }
                ],
                "goalLastResponse": {
                    "error": 'null',
                    "goalId": 53401,
                    "goalName": "US DC Test",
                    "details": [],
                    "totalDetails": {
                        "dimensions": [],
                        "dimensionValues": [],
                        "measurementValue": 108132.0,
                        "predictionSamplingValue": 108132.0,
                        "goalValue": 0.0,
                        "newGoalValue": 'null',
                        "periodStart": "2017-09-01",
                        "periodEnd": "2017-09-18",
                        "rateCalculationType": 'null',
                        "goalFillType": 'null',
                        "periodDaysElapsed": 18,
                        "periodDaysLeft": 0,
                        "remainingValue": -108132.0,
                        "dailyTarget": -108132.0,
                        "dailyAvgGoal": 0.0,
                        "dailyAvgValue": 6007.333333333333,
                        "predictedValue": 108132.0,
                        "deliveryRate": 0.0,
                        "goalStatus": "BAD"
                    },
                    "calcType": 'null',
                    "dingoException": 'null'
                },
                "goalRanges": [
                    85.0,
                    95.0
                ],
                "includeSun": 'true',
                "includeMon": 'true',
                "includeTue": 'true',
                "includeWed": 'true',
                "includeThu": 'true',
                "includeFri": 'true',
                "includeSat": 'true',
                "valuesFillType": "AUTO",
                "valuesFillMeasurement": "DELIVERY_MEDIA_COST",
                "predictionSamplingType": "GOAL_RANGE",
                "predictionSamplingDays": 'null',
                "rateCalculationType": "TARGET_UNTIL_TODAY",
                "emailNotificationSortBy": "DELIVERY_BUY_DATA_REMAINING_BUDGET",
                "emailNotificationSortOrder": "ACS",
                "actionsActive": 'false',
                "disableActionAfterRun": 'false',
                "actionsOnAchieve": [],
                "actionsOnNotAchieve": [],
                "actionsRunType": "EACH_ROW",
                "isCalcGoalNewWay": 'true'
            },
            "brandId": 11839,
            "target": 0.0,
            "targetType": "MIN_LIMIT",
            "dimensionTarget": 0.0,
            "dimensionTargetType": "MIN_LIMIT",
            "showInNotificationsPane": 'false',
            "emailRecipients": "",
            "goalMeasurement": "DELIVERY_BUY_DATA_REMAINING_BUDGET",
            "goalMeasurementType": "SUM",
            "goalType": "AT_LEAST",
            "periodGranularity": "DATE_DAY",
            "goalDimension": "MEDIA_BUY_KEY",
            "goalDimensionHierarchyId": 'null',
            "goalGranularity": "SINGLE_GOAL_FOR_ALL_ENTITIES",
            "originalId": 'null'
        }
    ],
    "actions": [],
    "brandHasPendingRules": 'false',
    "hasPendingCostCenter": 'false'
}

# %%
#List of data streams in the page filter
dataStreamList = jsonResponse["pageDto"]["config"]["filter"]["filterDims"]["BRAND_DATA_SOURCE_INSTANCE"]["vals"]

#Add a new data stream in the filters
dataStreamList.append('Random_Data_Stream')

# %%
#Dates in the page filter
startDate = jsonResponse["pageDto"]["config"]["filter"]["date"]["startDate"]
endDate = jsonResponse["pageDto"]["config"]["filter"]["date"]["endDate"]
dateType = jsonResponse["pageDto"]["config"]["filter"]["date"]["dateRangeType"]

#Update the start date in the filters
startDate = "2018-05-05"
endDate = "2022-05-05"
dateType = "CUSTOM"
